# %% [markdown]
# ### Here is another trial run

# %% [markdown]
# ####  ADS Project

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# initialise dataset
dproject = pd.read_csv('Data_ADS_Project_Total_CleanedAug2023.csv')

# %%
dproject.head()
# Out:
#    Serial Number Date of entry Gender                 Languages Spoken Class  \
# 0            1.0    17/02/2023      F                  English, Yoruba     5
# 1            2.0    17/02/2023      M  English, Yoruba, Pidgin English     4
# 2            3.0    17/02/2023      F                    English, Igbo     5
# 3            4.0    17/02/2023      M             English, Hausa, Bura     4
# 4            6.0    17/02/2023      M  English, Pidgin English, Gbagyi     3
#
#    Year of Entry            Language with Parents  \
# 0         2018.0                  English, Yoruba
# 1         2019.0          English, Pidgin English
# 2         2018.0                    English, Igbo
# 3         2019.0                    English, Bura
# 4         2020.0  English, Pidgin English, Gbagyi
#
#             Language with Siblings            Language with Friends  \
# 0                  English, Yoruba                  English, Yoruba
# 1          English, Pidgin English          English, Pidgin English
# 2                    English, Igbo                          English
# 3                          English                          English
# 4  English, Pidgin English, Gbagyi  English, Pidgin English, Gbagyi
#
#   Language in School First English at  Comprehension 1 Comprehension 2  \
# 0            English           At home               1               1
# 1            English    Primary School               1               1
# 2            English           At home               1               1
# 3            English        Play group               1               1
# 4            English    Primary School               1               1
#
#   Comprehension 3 Comprehension 4 Comprehension 5  Unnamed: 16
# 0               1               1               1          NaN
# 1               1               1               1          NaN
# 2               1               1               1          NaN
# 3               1               1               1          NaN
# 4               1               0               1          NaN

# %%
# Check the columns
dproject.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Serial Number           994 non-null    float64
#  1   Date of entry           999 non-null    object
#  2   Gender                  1001 non-null   object
#  3   Languages Spoken        1002 non-null   object
#  4   Class                   1004 non-null   object
#  5   Year of Entry           965 non-null    float64
#  6   Language with Parents   1002 non-null   object
#  7   Language with Siblings  994 non-null    object
#  8   Language with Friends   1000 non-null   object
#  9   Language in School      993 non-null    object
#  10  First English at        999 non-null    object
#  11  Comprehension 1         982 non-null    object
#  12  Comprehension 2         972 non-null    object
#  13  Comprehension 3         968 non-null    object
#  14  Comprehension 4         958 non-null    object
#  15  Comprehension 5         959 non-null    object
#  16  Unnamed: 16             0 non-null      float64
# dtypes: float64(3), object(14)
# memory usage: 133.6+ KB

# %%
#remove column 16
dproject.columns
# Out:
# Index(['Serial Number', 'Date of entry', 'Gender', 'Languages Spoken', 'Class',
#        'Year of Entry', 'Language with Parents', 'Language with Siblings',
#        'Language with Friends', 'Language in School', 'First English at ',
#        'Comprehension 1', 'Comprehension 2', 'Comprehension 3',
#        'Comprehension 4', 'Comprehension 5', 'Unnamed: 16'],
#       dtype='object')

# %%
#df.drop(['B', 'C'], axis=1)
dproject['Unnamed: 16'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Unnamed: 16, dtype: float64

# %%
# drop column 16
dproject.drop(['Unnamed: 16'], axis=1)
# Out:
#       Serial Number Date of entry Gender                 Languages Spoken  \
# 0               1.0    17/02/2023      F                  English, Yoruba
# 1               2.0    17/02/2023      M  English, Yoruba, Pidgin English
# 2               3.0    17/02/2023      F                    English, Igbo
# 3               4.0    17/02/2023      M             English, Hausa, Bura
# 4               6.0    17/02/2023      M  English, Pidgin English, Gbagyi
# ...             ...           ...    ...                              ...
# 1000            NaN    26-01-2023      F                              Tiv
# 1001            NaN    26-01-2023      M                           Gbagyi
# 1002            NaN    26-01-2023      F                          Yoruba.
# 1003            NaN    2023-07-02      M                           Gbagyi
# 1004            NaN    2023-07-02      F                  Yoruba, English
#
#      Class  Year of Entry            Language with Parents  \
# 0        5         2018.0                  English, Yoruba
# 1        4         2019.0          English, Pidgin English
# 2        5         2018.0                    English, Igbo
# 3        4         2019.0                    English, Bura
# 4        3         2020.0  English, Pidgin English, Gbagyi
# ...    ...            ...                              ...
# 1000     6            NaN          English, Pidgin English
# 1001     3         2020.0     English,Gbagyi,Pidgin, Hausa
# 1002     3            NaN    English,Pidgin English, Hausa
# 1003     3         2020.0                          English
# 1004     3         2020.0                  English, Yoruba
#
#                Language with Siblings            Language with Friends  \
# 0                     English, Yoruba                  English, Yoruba
# 1             English, Pidgin English          English, Pidgin English
# 2                       English, Igbo                          English
# 3                             English                          English
# 4     English, Pidgin English, Gbagyi  English, Pidgin English, Gbagyi
# ...                               ...                              ...
# 1000          English, Pidgin English          English, Pidgin English
# 1001                              NaN                   Pidgin English
# 1002                          Ebglish                          English
# 1003                          English                          English
# 1004                  English, Yoruba                          English
#
#      Language in School First English at  Comprehension 1 Comprehension 2  \
# 0               English           At home               1               1
# 1               English    Primary School               1               1
# 2               English           At home               1               1
# 3               English        Play group               1               1
# 4               English    Primary School               1               1
# ...                 ...               ...             ...             ...
# 1000            English    Primary School               1               1
# 1001            English         Playgroup               0             NaN
# 1002            English         Playgroup               0               1
# 1003            English    Primary School               1               1
# 1004            English           At home               1               1
#
#      Comprehension 3 Comprehension 4 Comprehension 5
# 0                  1               1               1
# 1                  1               1               1
# 2                  1               1               1
# 3                  1               1               1
# 4                  1               0               1
# ...              ...             ...             ...
# 1000               1               1               1
# 1001               0               0               0
# 1002               0               1               0
# 1003               1               0               1
# 1004               1               1               1
#
# [1005 rows x 16 columns]

# %%
dproject.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Serial Number           994 non-null    float64
#  1   Date of entry           999 non-null    object
#  2   Gender                  1001 non-null   object
#  3   Languages Spoken        1002 non-null   object
#  4   Class                   1004 non-null   object
#  5   Year of Entry           965 non-null    float64
#  6   Language with Parents   1002 non-null   object
#  7   Language with Siblings  994 non-null    object
#  8   Language with Friends   1000 non-null   object
#  9   Language in School      993 non-null    object
#  10  First English at        999 non-null    object
#  11  Comprehension 1         982 non-null    object
#  12  Comprehension 2         972 non-null    object
#  13  Comprehension 3         968 non-null    object
#  14  Comprehension 4         958 non-null    object
#  15  Comprehension 5         959 non-null    object
#  16  Unnamed: 16             0 non-null      float64
# dtypes: float64(3), object(14)
# memory usage: 133.6+ KB

# %%
dproject.describe()
# Out:
#        Serial Number  Year of Entry  Unnamed: 16
# count     994.000000     965.000000          0.0
# mean      490.615694    2018.502591          NaN
# std       311.880253       1.283975          NaN
# min         1.000000    2014.000000          NaN
# 25%       227.000000    2017.000000          NaN
# 50%       443.500000    2019.000000          NaN
# 75%       776.750000    2020.000000          NaN
# max      1800.000000    2022.000000          NaN

# %%
languages = dproject["Languages Spoken"].unique()
languages
# Out:
# array(['English, Yoruba', 'English, Yoruba, Pidgin English',
#        'English, Igbo', 'English, Hausa, Bura',
#        'English, Pidgin English, Gbagyi', 'English, Gbagyi, Hausa',
#        'Yoruba, English', 'English, Gbagyi', 'English, Idoma',
#        'English, Hausa, Gbagyi', 'English, Ijona, Pidgin English',
#        'English', 'English, Hausa', 'English, Tiv',
#        'English, Hausa, Tarok ', 'English, Akwa Ibom', 'English, Igala',
#        'English, Amo, Hausa', 'English, Tarok', 'Hausa, Fulfude',
#        'English, Gede, Fulfulde, Hausa', 'English, Fulfulde',
#        'English, Ngas', 'English, Mada', 'English, Cross River',
#        'English, Bassa', 'English, Eggon', 'English, Igon',
#        'Englis, Jabba , Hausa ', 'English, Kilber', 'English, Hausa, Tiv',
#        'English, Igede', 'English, Hausa, Idoma', 'Gbagyi, English',
#        'Tiv, Gbagyi', 'Bassa, Gbagyi, English', 'English, Hausa, Fulani',
#        'Gbagyi,Hausa,Mada, English', nan, 'English,Gbagyi,Hausa,Gade',
#        'Gbagyi,English,Hausa, Gade', 'English,Gbagyi,Hausa, Mada',
#        'Hausa,Gbagyi, English', 'English,Gbagyi, Hausa',
#        'English,Gbagyi, Mada', 'English, Gade', 'Gade, English',
#        'English,Gbagyi, Tiv', 'Gbagyi,Hausa, English', 'Tiv', 'Hausa',
#        'Gade', 'Gbagyi', 'Gbagyi  ', 'Tiv   ', 'English, Hausa, Ebira',
#        'Gbagyi, Hausa', 'Mada', 'Gbaagyi', 'Tiv, English', 'Gbagyi, Gade',
#        'Gbagyi, Mada', 'Gbagyi  , Hausa', 'Hausa, English, Gbagyi',
#        'English, Hausa, Gbagyi, Pidgin English',
#        'Gbagyi, Pidgin English, Hausa', 'Hausa, English', 'Fulfulde',
#        'Hausa, Fulfulde', 'Nupe, English', 'Ngas', 'Jaba', 'Basahge',
#        'Yoruba', 'Bassa', 'Narm, Gbagyi', 'Koro', '2018',
#        'English, Yoruba, Gbagyi', 'Igala, English', 'Gbagyi, Koro',
#        ' Gbagyi, Hausa', 'Kantana', 'English, Ganagana',
#        'English, Gbagyi ', 'English, Hausa, Gusawa', 'Igbo, English',
#        'English, Chawai', 'Gede', 'Yoruba ,English, Fulfulde', 'Cantana',
#        'English, Hausa, Eggon', 'Nupe', 'Igbo',
#        'English ,Hausa, Gbagyi, Koro', 'Attakar', 'Kurama',
#        'English, Hausa, Bajju', 'Gbagyi, Gede',
#        'Pidgin English, Gede, Hausa', 'Chala', 'Yoruba ,English',
#        'Pidgin English, Hausa, Chawai', ' English',
#        'Pidgin English, Gbagyi', 'English, Ahor, Hausa',
#        'Pidgin English,  Hausa, Tiv', 'Bassa, English',
#        'English, Basange', 'English, Hausa, Gbagyi, Afo', 'Arago',
#        'English, Gede', 'English, Tiv, Hausa', 'English, Tiv, Hausa ',
#        'English, Hausa, Gede', 'Kwala',
#        'English,Pidin English,Hausa, Gede', 'English, TIV',
#        'English, Chawel', 'English, Bassa, Hausa',
#        'English, Hausa, Gwandara', 'Englis, Hausa, Tiv',
#        'English, Gbagyi , Hausa', 'Gbagyi, Hausa  ',
#        'Pidgin English, Hausa', 'Pidgin English',
#        'Tiv, Hausa, Pidgin English', 'English, Fulfulde, Hausa ',
#        'Pidgin English, Hausa, Tiv', 'English, Pidgin English',
#        'Pidgin English, Hausa, Gbagyi', 'Gbagyi, Pidgin English',
#        'Pidgin English, Gede', 'Hausa, Tiv', 'Gede, English',
#        'English, Pidgin English, Gede', 'Pidgin English, Hausa , Gede',
#        'English,  Tiv, Hausa', 'English, Tiv ', 'English, Jaba',
#        'English, Madar', 'English, Pidgin English, Tiv', 'English ',
#        'Englisha, Igbira', 'Igala', 'Kwol', 'English, Kaduna', 'Edo',
#        'Bajju', 'Ebira', 'Angas', 'Ahoe', 'Idoma', 'Gbagy',
#        'English, Ron', 'English, Edo', 'Boju', 'Bura', 'Gbagyi, Yoruba',
#        'English,Hausa, Yoruba', 'Yoruba, Igbo', 'Awo', 'Efik',
#        'English, Ibibio(Akwa-Ibom', 'English, Kataf',
#        'English,Hausa, Adara', 'English,Hausa, Atarkar',
#        'English,Hausa,Fulfude', 'English, Margi', 'Katab', 'Yoruba.'],
#       dtype=object)

# %%
# SAMPLE code:  perform one hot encoding using get_dummies
# df_onehot = pd.get_dummies(df['Gender'])

# add the one hot encoded columns to the original dataframe
# df = pd.concat([df, df_onehot], axis=1)

# print(df)

df_onehot = pd.get_dummies(dproject['Gender'])

dproject=pd.concat([dproject, df_onehot], axis=1)

print(dproject.head())
# Out:
#    Serial Number Date of entry Gender                 Languages Spoken Class  \
# 0            1.0    17/02/2023      F                  English, Yoruba     5
# 1            2.0    17/02/2023      M  English, Yoruba, Pidgin English     4
# 2            3.0    17/02/2023      F                    English, Igbo     5
# 3            4.0    17/02/2023      M             English, Hausa, Bura     4
# 4            6.0    17/02/2023      M  English, Pidgin English, Gbagyi     3
#
#    Year of Entry            Language with Parents  \
# 0         2018.0                  English, Yoruba
# 1         2019.0          English, Pidgin English
# 2         2018.0                    English, Igbo
# 3         2019.0                    English, Bura
# 4         2020.0  English, Pidgin English, Gbagyi
#
#             Language with Siblings            Language with Friends  \
# 0                  English, Yoruba                  English, Yoruba
# 1          English, Pidgin English          English, Pidgin English
# 2                    English, Igbo                          English
# 3                          English                          English
# 4  English, Pidgin English, Gbagyi  English, Pidgin English, Gbagyi
#
#   Language in School First English at  Comprehension 1 Comprehension 2  \
# 0            English           At home               1               1
# 1            English    Primary School               1               1
# 2            English           At home               1               1
# 3            English        Play group               1               1
# 4            English    Primary School               1               1
#
#   Comprehension 3 Comprehension 4 Comprehension 5  Unnamed: 16   F  F  M
# 0               1               1               1          NaN   0  1  0
# 1               1               1               1          NaN   0  0  1
# 2               1               1               1          NaN   0  1  0
# 3               1               1               1          NaN   0  0  1
# 4               1               0               1          NaN   0  0  1

# %%
#how many distinct languages are represented...
languages = dproject["Languages Spoken"].nunique()
languages
# Out:
# 170

# %%
# Hmmm this cant be true , it must be capturing combinations as distinct...
# How to separate them...
#df[["Score1", "Score2", "Score3"]] = df["score"].str.split(",", expand=True)
dproject[["Lang1", "Lang2", "Lang3", "Lang4"]] = dproject["Languages Spoken"].str.split(",", expand=True)
# ref...https://medium.com/@akaivdo/how-to-split-one-column-to-multiple-columns-in-pandas-3c857b47fbde

# %%
dproject.head()
# Out:
#    Serial Number Date of entry Gender                 Languages Spoken Class  \
# 0            1.0    17/02/2023      F                  English, Yoruba     5
# 1            2.0    17/02/2023      M  English, Yoruba, Pidgin English     4
# 2            3.0    17/02/2023      F                    English, Igbo     5
# 3            4.0    17/02/2023      M             English, Hausa, Bura     4
# 4            6.0    17/02/2023      M  English, Pidgin English, Gbagyi     3
#
#    Year of Entry            Language with Parents  \
# 0         2018.0                  English, Yoruba
# 1         2019.0          English, Pidgin English
# 2         2018.0                    English, Igbo
# 3         2019.0                    English, Bura
# 4         2020.0  English, Pidgin English, Gbagyi
#
#             Language with Siblings            Language with Friends  \
# 0                  English, Yoruba                  English, Yoruba
# 1          English, Pidgin English          English, Pidgin English
# 2                    English, Igbo                          English
# 3                          English                          English
# 4  English, Pidgin English, Gbagyi  English, Pidgin English, Gbagyi
#
#   Language in School  ... Comprehension 4 Comprehension 5 Unnamed: 16  F  F  \
# 0            English  ...               1               1         NaN  0  1
# 1            English  ...               1               1         NaN  0  0
# 2            English  ...               1               1         NaN  0  1
# 3            English  ...               1               1         NaN  0  0
# 4            English  ...               0               1         NaN  0  0
#
#    M    Lang1            Lang2            Lang3  Lang4
# 0  0  English           Yoruba             None   None
# 1  1  English           Yoruba   Pidgin English   None
# 2  0  English             Igbo             None   None
# 3  1  English            Hausa             Bura   None
# 4  1  English   Pidgin English           Gbagyi   None
#
# [5 rows x 24 columns]

# %%
dproject.describe()
# Out:
#        Serial Number  Year of Entry  Unnamed: 16            F            F  \
# count     994.000000     965.000000          0.0  1005.000000  1005.000000
# mean      490.615694    2018.502591          NaN     0.000995     0.518408
# std       311.880253       1.283975          NaN     0.031544     0.499910
# min         1.000000    2014.000000          NaN     0.000000     0.000000
# 25%       227.000000    2017.000000          NaN     0.000000     0.000000
# 50%       443.500000    2019.000000          NaN     0.000000     1.000000
# 75%       776.750000    2020.000000          NaN     0.000000     1.000000
# max      1800.000000    2022.000000          NaN     1.000000     1.000000
#
#                  M
# count  1005.000000
# mean      0.476617
# std       0.499702
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
dproject.drop(['Unnamed: 16'], axis =1)
# Out:
#       Serial Number Date of entry Gender                 Languages Spoken  \
# 0               1.0    17/02/2023      F                  English, Yoruba
# 1               2.0    17/02/2023      M  English, Yoruba, Pidgin English
# 2               3.0    17/02/2023      F                    English, Igbo
# 3               4.0    17/02/2023      M             English, Hausa, Bura
# 4               6.0    17/02/2023      M  English, Pidgin English, Gbagyi
# ...             ...           ...    ...                              ...
# 1000            NaN    26-01-2023      F                              Tiv
# 1001            NaN    26-01-2023      M                           Gbagyi
# 1002            NaN    26-01-2023      F                          Yoruba.
# 1003            NaN    2023-07-02      M                           Gbagyi
# 1004            NaN    2023-07-02      F                  Yoruba, English
#
#      Class  Year of Entry            Language with Parents  \
# 0        5         2018.0                  English, Yoruba
# 1        4         2019.0          English, Pidgin English
# 2        5         2018.0                    English, Igbo
# 3        4         2019.0                    English, Bura
# 4        3         2020.0  English, Pidgin English, Gbagyi
# ...    ...            ...                              ...
# 1000     6            NaN          English, Pidgin English
# 1001     3         2020.0     English,Gbagyi,Pidgin, Hausa
# 1002     3            NaN    English,Pidgin English, Hausa
# 1003     3         2020.0                          English
# 1004     3         2020.0                  English, Yoruba
#
#                Language with Siblings            Language with Friends  \
# 0                     English, Yoruba                  English, Yoruba
# 1             English, Pidgin English          English, Pidgin English
# 2                       English, Igbo                          English
# 3                             English                          English
# 4     English, Pidgin English, Gbagyi  English, Pidgin English, Gbagyi
# ...                               ...                              ...
# 1000          English, Pidgin English          English, Pidgin English
# 1001                              NaN                   Pidgin English
# 1002                          Ebglish                          English
# 1003                          English                          English
# 1004                  English, Yoruba                          English
#
#      Language in School  ... Comprehension 3 Comprehension 4 Comprehension 5  \
# 0               English  ...               1               1               1
# 1               English  ...               1               1               1
# 2               English  ...               1               1               1
# 3               English  ...               1               1               1
# 4               English  ...               1               0               1
# ...                 ...  ...             ...             ...             ...
# 1000            English  ...               1               1               1
# 1001            English  ...               0               0               0
# 1002            English  ...               0               1               0
# 1003            English  ...               1               0               1
# 1004            English  ...               1               1               1
#
#       F  F  M    Lang1            Lang2            Lang3 Lang4
# 0     0  1  0  English           Yoruba             None  None
# 1     0  0  1  English           Yoruba   Pidgin English  None
# 2     0  1  0  English             Igbo             None  None
# 3     0  0  1  English            Hausa             Bura  None
# 4     0  0  1  English   Pidgin English           Gbagyi  None
# ...  .. .. ..      ...              ...              ...   ...
# 1000  0  1  0      Tiv             None             None  None
# 1001  0  0  1   Gbagyi             None             None  None
# 1002  0  1  0  Yoruba.             None             None  None
# 1003  0  0  1   Gbagyi             None             None  None
# 1004  0  1  0   Yoruba          English             None  None
#
# [1005 rows x 23 columns]

# %%
plt.hist(dproject['Year of Entry'])
plt.xlabel('Year of Entry')
plt.ylabel('Count')
plt.title('Simple plot')
plt.show()

# %%
dproject.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Serial Number           994 non-null    float64
#  1   Date of entry           999 non-null    object
#  2   Gender                  1001 non-null   object
#  3   Languages Spoken        1002 non-null   object
#  4   Class                   1004 non-null   object
#  5   Year of Entry           965 non-null    float64
#  6   Language with Parents   1002 non-null   object
#  7   Language with Siblings  994 non-null    object
#  8   Language with Friends   1000 non-null   object
#  9   Language in School      993 non-null    object
#  10  First English at        999 non-null    object
#  11  Comprehension 1         982 non-null    object
#  12  Comprehension 2         972 non-null    object
#  13  Comprehension 3         968 non-null    object
#  14  Comprehension 4         958 non-null    object
#  15  Comprehension 5         959 non-null    object
#  16  Unnamed: 16             0 non-null      float64
#  17   F                      1005 non-null   uint8
#  18  F                       1005 non-null   uint8
#  19  M                       1005 non-null   uint8
#  20  Lang1                   1002 non-null   object
#  21  Lang2                   601 non-null    object
#  22  Lang3                   93 non-null     object
#  23  Lang4                   9 non-null      object
# dtypes: float64(3), object(18), uint8(3)
# memory usage: 168.0+ KB
